# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('ggplot')
sns.set()

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import r2_score,mean_squared_error
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split, GridSearchCV

from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_curve, auc

# %%
df = pd.read_csv('train.csv',index_col=False)
df.head()
# Out:
#           ID    Source    TMC  Severity           Start_Time  \
# 0  A-2017855  MapQuest  201.0         2  2018-07-19 20:30:23
# 1  A-3340193      Bing    NaN         2  2020-12-27 13:22:48
# 2  A-3274372      Bing    NaN         2  2020-12-19 20:27:52
# 3  A-2782559      Bing    NaN         3  2016-09-27 17:29:27
# 4  A-3722269      Bing    NaN         2  2020-02-11 19:22:00
#
#               End_Time  Start_Lat   Start_Lng    End_Lat     End_Lng  ...  \
# 0  2018-07-19 21:14:11  34.153896 -118.275482        NaN         NaN  ...
# 1  2020-12-27 15:02:42  40.261747  -75.250020  40.263001  -75.251072  ...
# 2  2020-12-19 22:23:39  29.980875  -90.073829  29.981676  -90.073111  ...
# 3  2016-09-27 23:29:27  39.018870  -77.102890  39.019580  -77.107080  ...
# 4  2020-02-11 23:22:00  45.743940 -120.175670  45.743940 -120.175670  ...
#
#    Roundabout Station   Stop Traffic_Calming Traffic_Signal Turning_Loop  \
# 0       False   False  False           False          False        False
# 1       False   False  False           False          False        False
# 2       False   False  False           False          False        False
# 3       False   False  False           False          False        False
# 4       False   False  False           False          False        False
#
#   Sunrise_Sunset Civil_Twilight Nautical_Twilight Astronomical_Twilight
# 0          Night            Day               Day                   Day
# 1            Day            Day               Day                   Day
# 2          Night          Night             Night                 Night
# 3            Day            Day               Day                   Day
# 4          Night          Night             Night                 Night
#
# [5 rows x 49 columns]

# %%
df['Severity'] = (df['Severity'] > 2) * 1
df.head()
# Out:
#           ID    Source    TMC  Severity           Start_Time  \
# 0  A-2017855  MapQuest  201.0         0  2018-07-19 20:30:23
# 1  A-3340193      Bing    NaN         0  2020-12-27 13:22:48
# 2  A-3274372      Bing    NaN         0  2020-12-19 20:27:52
# 3  A-2782559      Bing    NaN         1  2016-09-27 17:29:27
# 4  A-3722269      Bing    NaN         0  2020-02-11 19:22:00
#
#               End_Time  Start_Lat   Start_Lng    End_Lat     End_Lng  ...  \
# 0  2018-07-19 21:14:11  34.153896 -118.275482        NaN         NaN  ...
# 1  2020-12-27 15:02:42  40.261747  -75.250020  40.263001  -75.251072  ...
# 2  2020-12-19 22:23:39  29.980875  -90.073829  29.981676  -90.073111  ...
# 3  2016-09-27 23:29:27  39.018870  -77.102890  39.019580  -77.107080  ...
# 4  2020-02-11 23:22:00  45.743940 -120.175670  45.743940 -120.175670  ...
#
#    Roundabout Station   Stop Traffic_Calming Traffic_Signal Turning_Loop  \
# 0       False   False  False           False          False        False
# 1       False   False  False           False          False        False
# 2       False   False  False           False          False        False
# 3       False   False  False           False          False        False
# 4       False   False  False           False          False        False
#
#   Sunrise_Sunset Civil_Twilight Nautical_Twilight Astronomical_Twilight
# 0          Night            Day               Day                   Day
# 1            Day            Day               Day                   Day
# 2          Night          Night             Night                 Night
# 3            Day            Day               Day                   Day
# 4          Night          Night             Night                 Night
#
# [5 rows x 49 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2962779 entries, 0 to 2962778
# Data columns (total 49 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Source                 object
#  2   TMC                    float64
#  3   Severity               int32
#  4   Start_Time             object
#  5   End_Time               object
#  6   Start_Lat              float64
#  7   Start_Lng              float64
#  8   End_Lat                float64
#  9   End_Lng                float64
#  10  Distance.mi.           float64
#  11  Description            object
#  12  Number                 float64
#  13  Street                 object
#  14  Side                   object
#  15  City                   object
#  16  County                 object
#  17  State                  object
#  18  Zipcode                object
#  19  Country                object
#  20  Timezone               object
#  21  Airport_Code           object
#  22  Weather_Timestamp      object
#  23  Temperature.F.         float64
#  24  Wind_Chill.F.          float64
#  25  Humidity...            float64
#  26  Pressure.in.           float64
#  27  Visibility.mi.         float64
#  28  Wind_Direction         object
#  29  Wind_Speed.mph.        float64
#  30  Precipitation.in.      float64
#  31  Weather_Condition      object
#  32  Amenity                bool
#  33  Bump                   bool
#  34  Crossing               bool
#  35  Give_Way               bool
#  36  Junction               bool
#  37  No_Exit                bool
#  38  Railway                bool
#  39  Roundabout             bool
#  40  Station                bool
#  41  Stop                   bool
#  42  Traffic_Calming        bool
#  43  Traffic_Signal         bool
#  44  Turning_Loop           bool
#  45  Sunrise_Sunset         object
#  46  Civil_Twilight         object
#  47  Nautical_Twilight      object
#  48  Astronomical_Twilight  object
# dtypes: bool(13), float64(14), int32(1), object(21)
# memory usage: 839.2+ MB

# %%
df['Start_Time'] = pd.to_datetime(df['Start_Time'], errors='coerce')
df['End_Time'] = pd.to_datetime(df['End_Time'], errors='coerce')

# Extract year, month, day, hour and weekday
df['month']=df['Start_Time'].dt.strftime('%b')
df['Hour']=df['Start_Time'].dt.hour
df['Weekday']=df['Start_Time'].dt.strftime('%a')

# Extract the amount of time in the unit of minutes for each accident, round to the nearest integer
timed='Time_Duration(min)'
df[timed]=round((df['End_Time']-df['Start_Time'])/np.timedelta64(1,'m'))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2962779 entries, 0 to 2962778
# Data columns (total 53 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Source                 object
#  2   TMC                    float64
#  3   Severity               int32
#  4   Start_Time             datetime64[ns]
#  5   End_Time               datetime64[ns]
#  6   Start_Lat              float64
#  7   Start_Lng              float64
#  8   End_Lat                float64
#  9   End_Lng                float64
#  10  Distance.mi.           float64
#  11  Description            object
#  12  Number                 float64
#  13  Street                 object
#  14  Side                   object
#  15  City                   object
#  16  County                 object
#  17  State                  object
#  18  Zipcode                object
#  19  Country                object
#  20  Timezone               object
#  21  Airport_Code           object
#  22  Weather_Timestamp      object
#  23  Temperature.F.         float64
#  24  Wind_Chill.F.          float64
#  25  Humidity...            float64
#  26  Pressure.in.           float64
#  27  Visibility.mi.         float64
#  28  Wind_Direction         object
#  29  Wind_Speed.mph.        float64
#  30  Precipitation.in.      float64
#  31  Weather_Condition      object
#  32  Amenity                bool
#  33  Bump                   bool
#  34  Crossing               bool
#  35  Give_Way               bool
#  36  Junction               bool
#  37  No_Exit                bool
#  38  Railway                bool
#  39  Roundabout             bool
#  40  Station                bool
#  41  Stop                   bool
#  42  Traffic_Calming        bool
#  43  Traffic_Signal         bool
#  44  Turning_Loop           bool
#  45  Sunrise_Sunset         object
#  46  Civil_Twilight         object
#  47  Nautical_Twilight      object
#  48  Astronomical_Twilight  object
#  49  month                  object
#  50  Hour                   int64
#  51  Weekday                object
#  52  Time_Duration(min)     float64
# dtypes: bool(13), datetime64[ns](2), float64(15), int32(1), int64(1), object(21)
# memory usage: 929.6+ MB

# %%
# Check if there is any negative time_duration values
df[timed][df[timed]<=0]
# Out:
# Series([], Name: Time_Duration(min), dtype: float64)

# %%
# Drop the rows with td<0

neg_outliers=df[timed]<=0

# Set outliers to NAN
df[neg_outliers] = np.nan

# Drop rows with negative td
df.dropna(subset=[timed],axis=0,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2962779 entries, 0 to 2962778
# Data columns (total 53 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Source                 object
#  2   TMC                    float64
#  3   Severity               float64
#  4   Start_Time             datetime64[ns]
#  5   End_Time               datetime64[ns]
#  6   Start_Lat              float64
#  7   Start_Lng              float64
#  8   End_Lat                float64
#  9   End_Lng                float64
#  10  Distance.mi.           float64
#  11  Description            object
#  12  Number                 float64
#  13  Street                 object
#  14  Side                   object
#  15  City                   object
#  16  County                 object
#  17  State                  object
#  18  Zipcode                object
#  19  Country                object
#  20  Timezone               object
#  21  Airport_Code           object
#  22  Weather_Timestamp      object
#  23  Temperature.F.         float64
#  24  Wind_Chill.F.          float64
#  25  Humidity...            float64
#  26  Pressure.in.           float64
#  27  Visibility.mi.         float64
#  28  Wind_Direction         object
#  29  Wind_Speed.mph.        float64
#  30  Precipitation.in.      float64
#  31  Weather_Condition      object
#  32  Amenity                float64
#  33  Bump                   float64
#  34  Crossing               float64
#  35  Give_Way               float64
#  36  Junction               float64
#  37  No_Exit                float64
#  38  Railway                float64
#  39  Roundabout             float64
#  40  Station                float64
#  41  Stop                   float64
#  42  Traffic_Calming        float64
#  43  Traffic_Signal         float64
#  44  Turning_Loop           float64
#  45  Sunrise_Sunset         object
#  46  Civil_Twilight         object
#  47  Nautical_Twilight      object
#  48  Astronomical_Twilight  object
#  49  month                  object
#  50  Hour                   float64
#  51  Weekday                object
#  52  Time_Duration(min)     float64
# dtypes: datetime64[ns](2), float64(30), object(21)
# memory usage: 1.2+ GB

# %%
# Remove outliers for Time_Duration(min): n * standard_deviation (n=3), backfill with median

n=3

median = df[timed].median()
std = df[timed].std()
outliers = (df[timed] - median).abs() > std*n

# Set outliers to NAN
df[outliers] = np.nan

# Fill NAN with median
df[timed].fillna(median, inplace=True)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2962779 entries, 0 to 2962778
# Data columns (total 53 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Source                 object
#  2   TMC                    float64
#  3   Severity               float64
#  4   Start_Time             datetime64[ns]
#  5   End_Time               datetime64[ns]
#  6   Start_Lat              float64
#  7   Start_Lng              float64
#  8   End_Lat                float64
#  9   End_Lng                float64
#  10  Distance.mi.           float64
#  11  Description            object
#  12  Number                 float64
#  13  Street                 object
#  14  Side                   object
#  15  City                   object
#  16  County                 object
#  17  State                  object
#  18  Zipcode                object
#  19  Country                object
#  20  Timezone               object
#  21  Airport_Code           object
#  22  Weather_Timestamp      object
#  23  Temperature.F.         float64
#  24  Wind_Chill.F.          float64
#  25  Humidity...            float64
#  26  Pressure.in.           float64
#  27  Visibility.mi.         float64
#  28  Wind_Direction         object
#  29  Wind_Speed.mph.        float64
#  30  Precipitation.in.      float64
#  31  Weather_Condition      object
#  32  Amenity                float64
#  33  Bump                   float64
#  34  Crossing               float64
#  35  Give_Way               float64
#  36  Junction               float64
#  37  No_Exit                float64
#  38  Railway                float64
#  39  Roundabout             float64
#  40  Station                float64
#  41  Stop                   float64
#  42  Traffic_Calming        float64
#  43  Traffic_Signal         float64
#  44  Turning_Loop           float64
#  45  Sunrise_Sunset         object
#  46  Civil_Twilight         object
#  47  Nautical_Twilight      object
#  48  Astronomical_Twilight  object
#  49  month                  object
#  50  Hour                   float64
#  51  Weekday                object
#  52  Time_Duration(min)     float64
# dtypes: datetime64[ns](2), float64(30), object(21)
# memory usage: 1.2+ GB

# %%
df['Severity']

# %%
# Print time_duration information
print('Max time to clear an accident: {} minutes or {} hours or {} days; Min to clear an accident td: {} minutes.'.format(df[timed].max(),round(df[timed].max()/60), round(df[timed].max()/60/24), df[timed].min()))
# Out:
# Max time to clear an accident: 10588.0 minutes or 176 hours or 7 days; Min to clear an accident td: 1.0 minutes.

# %%
feature_lst=['Source','TMC','Severity','Start_Lng','Start_Lat',
             'Distance.mi.','Side','City','County','State','Timezone',
             'Temperature.F.','Humidity...','Pressure.in.', 
             'Visibility.mi.', 'Wind_Direction','Weather_Condition',
             'Amenity','Bump','Crossing','Give_Way','Junction','No_Exit',
             'Railway','Roundabout','Station','Stop','Traffic_Calming',
             'Traffic_Signal','Turning_Loop','Sunrise_Sunset','Hour',
             'Weekday', 'Time_Duration(min)']

# %%
# Select the dataset to include only the selected features
df_sel=df[feature_lst].copy()

# %%
df_sel.to_csv('new_cleaned_train.csv')

# %%
# Check missing values
df_sel.isna().mean()
# Out:
# Source                0.0
# TMC                   0.0
# Severity              0.0
# Start_Lng             0.0
# Start_Lat             0.0
# Distance.mi.          0.0
# Side                  0.0
# City                  0.0
# County                0.0
# State                 0.0
# Timezone              0.0
# Temperature.F.        0.0
# Humidity...           0.0
# Pressure.in.          0.0
# Visibility.mi.        0.0
# Wind_Direction        0.0
# Weather_Condition     0.0
# Amenity               0.0
# Bump                  0.0
# Crossing              0.0
# Give_Way              0.0
# Junction              0.0
# No_Exit               0.0
# Railway               0.0
# Roundabout            0.0
# Station               0.0
# Stop                  0.0
# Traffic_Calming       0.0
# Traffic_Signal        0.0
# Turning_Loop          0.0
# Sunrise_Sunset        0.0
# Hour                  0.0
# Weekday               0.0
# Time_Duration(min)    0.0
# dtype: float64

# %%
df_sel.dropna(subset=df_sel.columns[df_sel.isnull().mean()!=0], how='any', axis=0, inplace=True)
df_sel.shape
# Out:
# (1846028, 34)

# %%
df_ohe = pd.get_dummies(df_sel,drop_first=True)

# %%
df_sel = df_ohe
df_sel.columns
# Out:
# Index(['TMC', 'Severity', 'Start_Lng', 'Start_Lat', 'Distance.mi.',
#        'Temperature.F.', 'Humidity...', 'Pressure.in.', 'Visibility.mi.',
#        'Amenity',
#        ...
#        'Weather_Condition_Widespread Dust', 'Weather_Condition_Wintry Mix',
#        'Weather_Condition_Wintry Mix / Windy', 'Sunrise_Sunset_Night',
#        'Weekday_Mon', 'Weekday_Sat', 'Weekday_Sun', 'Weekday_Thu',
#        'Weekday_Tue', 'Weekday_Wed'],
#       dtype='object', length=11669)

# %%
df_sel_chunk1, drop = train_test_split(df_sel, test_size=0.40, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-32-07ff526f85f1> in <module>
# ----> 1 df_sel_chunk1, drop = train_test_split(df_sel, test_size=0.40, random_state=42)
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(*arrays, **options)
#    2144
#    2145     return list(chain.from_iterable((_safe_indexing(a, train),
# -> 2146                                      _safe_indexing(a, test)) for a in arrays))
#    2147
#    2148
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_split.py in <genexpr>(.0)
#    2144
#    2145     return list(chain.from_iterable((_safe_indexing(a, train),
# -> 2146                                      _safe_indexing(a, test)) for a in arrays))
#    2147
#    2148
#
# ~\anaconda3\lib\site-packages\sklearn\utils\__init__.py in _safe_indexing(X, indices, axis)
#     409
#     410     if hasattr(X, "iloc"):
# --> 411         return _pandas_indexing(X, indices, indices_dtype, axis=axis)
#     412     elif hasattr(X, "shape"):
#     413         return _array_indexing(X, indices, indices_dtype, axis=axis)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\__init__.py in _pandas_indexing(X, key, key_dtype, axis)
#     211     # check whether we should index with loc or iloc
#     212     indexer = X.iloc if key_dtype == 'int' else X.loc
# --> 213     return indexer[:, key] if axis else indexer[key]
#     214
#     215
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1765
#    1766             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1767             return self._getitem_axis(maybe_callable, axis=axis)
#    1768
#    1769     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    2126         # a list of integers
#    2127         elif is_list_like_indexer(key):
# -> 2128             return self._get_list_axis(key, axis=axis)
#    2129
#    2130         # a single integer
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_list_axis(self, key, axis)
#    2108         """
#    2109         try:
# -> 2110             return self.obj._take_with_is_copy(key, axis=axis)
#    2111         except IndexError:
#    2112             # re-raise with different error message
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _take_with_is_copy(self, indices, axis, **kwargs)
#    3407         See the docstring of `take` for full explanation of the parameters.
#    3408         """
# -> 3409         result = self.take(indices=indices, axis=axis, **kwargs)
#    3410         # Maybe set copy if we didn't actually change the index.
#    3411         if not result._get_axis(axis).equals(self._get_axis(axis)):
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in take(self, indices, axis, is_copy, **kwargs)
#    3390         nv.validate_take(tuple(), kwargs)
#    3391
# -> 3392         self._consolidate_inplace()
#    3393
#    3394         new_data = self._data.take(
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _consolidate_inplace(self)
#    5345             self._data = self._data.consolidate()
#    5346
# -> 5347         self._protect_consolidate(f)
#    5348
#    5349     def _consolidate(self, inplace: bool_t = False):
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _protect_consolidate(self, f)
#    5334         """
#    5335         blocks_before = len(self._data.blocks)
# -> 5336         result = f()
#    5337         if len(self._data.blocks) != blocks_before:
#    5338             self._clear_item_cache()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in f()
#    5343
#    5344         def f():
# -> 5345             self._data = self._data.consolidate()
#    5346
#    5347         self._protect_consolidate(f)
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in consolidate(self)
#     938         bm = type(self)(self.blocks, self.axes)
#     939         bm._is_consolidated = False
# --> 940         bm._consolidate_inplace()
#     941         return bm
#     942
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in _consolidate_inplace(self)
#     943     def _consolidate_inplace(self):
#     944         if not self.is_consolidated():
# --> 945             self.blocks = tuple(_consolidate(self.blocks))
#     946             self._is_consolidated = True
#     947             self._known_consolidated = True
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in _consolidate(blocks)
#    1885     for (_can_consolidate, dtype), group_blocks in grouper:
#    1886         merged_blocks = _merge_blocks(
# -> 1887             list(group_blocks), dtype=dtype, _can_consolidate=_can_consolidate
#    1888         )
#    1889         new_blocks = _extend_blocks(merged_blocks, new_blocks)
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in _merge_blocks(blocks, dtype, _can_consolidate)
#    3094
#    3095         argsort = np.argsort(new_mgr_locs)
# -> 3096         new_values = new_values[argsort]
#    3097         new_mgr_locs = new_mgr_locs[argsort]
#    3098
#
# MemoryError: Unable to allocate 20.0 GiB for an array with shape (11645, 1846028) and data type uint8

# %%
df_sel.to_csv('new_cleaned_train.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-2634eb1feeee> in <module>
# ----> 1 df_sel.to_csv('new_cleaned_train.csv')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3202             decimal=decimal,
#    3203         )
# -> 3204         formatter.save()
#    3205
#    3206         if path_or_buf is None:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     202             )
#     203
# --> 204             self._save()
#     205
#     206         finally:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in _save(self)
#     321                 break
#     322
# --> 323             self._save_chunk(start_i, end_i)
#     324
#     325     def _save_chunk(self, start_i: int, end_i: int) -> None:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in _save_chunk(self, start_i, end_i)
#     336                 decimal=self.decimal,
#     337                 date_format=self.date_format,
# --> 338                 quoting=self.quoting,
#     339             )
#     340
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in to_native_types(self, slicer, na_rep, quoting, **kwargs)
#     677         if slicer is not None:
#     678             values = values[:, slicer]
# --> 679         mask = isna(values)
#     680         itemsize = writers.word_len(na_rep)
#     681
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py in isna(obj)
#     124     Name: 1, dtype: bool
#     125     """
# --> 126     return _isna(obj)
#     127
#     128
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py in _isna_new(obj)
#     150         ),
#     151     ):
# --> 152         return _isna_ndarraylike(obj)
#     153     elif isinstance(obj, ABCGeneric):
#     154         return obj._constructor(obj._data.isna(func=isna))
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py in _isna_ndarraylike(obj)
#     260         result = values.view("i8") == iNaT
#     261     else:
# --> 262         result = np.isnan(values)
#     263
#     264     # box
#
# KeyboardInterrupt:

# %%
X = df_sel.drop(columns=['Severity'],inplace=True)
Y = df_sel['Severity']
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-28-1f1fdf2ecea1> in <module>
# ----> 1 X = df_sel.drop(columns=['Severity'],inplace=True)
#       2 Y = df_sel['Severity']
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3969             else:
#    3970                 new_axis = axis.drop(labels, errors=errors)
# -> 3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#    3973         # Case for non-unique axis
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     225         @wraps(func)
#     226         def wrapper(*args, **kwargs) -> Callable[..., Any]:
# --> 227             return func(*args, **kwargs)
#     228
#     229         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in reindex(self, *args, **kwargs)
#    3854         kwargs.pop("axis", None)
#    3855         kwargs.pop("labels", None)
# -> 3856         return self._ensure_type(super().reindex(**kwargs))
#    3857
#    3858     def drop(
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in reindex(self, *args, **kwargs)
#    4523             )
#    4524
# -> 4525         self._consolidate_inplace()
#    4526
#    4527         # if all axes that are requested to reindex are equal, then only copy
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _consolidate_inplace(self)
#    5345             self._data = self._data.consolidate()
#    5346
# -> 5347         self._protect_consolidate(f)
#    5348
#    5349     def _consolidate(self, inplace: bool_t = False):
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _protect_consolidate(self, f)
#    5334         """
#    5335         blocks_before = len(self._data.blocks)
# -> 5336         result = f()
#    5337         if len(self._data.blocks) != blocks_before:
#    5338             self._clear_item_cache()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in f()
#    5343
#    5344         def f():
# -> 5345             self._data = self._data.consolidate()
#    5346
#    5347         self._protect_consolidate(f)
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in consolidate(self)
#     938         bm = type(self)(self.blocks, self.axes)
#     939         bm._is_consolidated = False
# --> 940         bm._consolidate_inplace()
#     941         return bm
#     942
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in _consolidate_inplace(self)
#     943     def _consolidate_inplace(self):
#     944         if not self.is_consolidated():
# --> 945             self.blocks = tuple(_consolidate(self.blocks))
#     946             self._is_consolidated = True
#     947             self._known_consolidated = True
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in _consolidate(blocks)
#    1885     for (_can_consolidate, dtype), group_blocks in grouper:
#    1886         merged_blocks = _merge_blocks(
# -> 1887             list(group_blocks), dtype=dtype, _can_consolidate=_can_consolidate
#    1888         )
#    1889         new_blocks = _extend_blocks(merged_blocks, new_blocks)
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in _merge_blocks(blocks, dtype, _can_consolidate)
#    3091         # combination of those slices is a slice, too.
#    3092         new_mgr_locs = np.concatenate([b.mgr_locs.as_array for b in blocks])
# -> 3093         new_values = np.vstack([b.values for b in blocks])
#    3094
#    3095         argsort = np.argsort(new_mgr_locs)
#
# <__array_function__ internals> in vstack(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\core\shape_base.py in vstack(tup)
#     281     if not isinstance(arrs, list):
#     282         arrs = [arrs]
# --> 283     return _nx.concatenate(arrs, 0)
#     284
#     285
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# MemoryError: Unable to allocate 20.0 GiB for an array with shape (11645, 1846028) and data type uint8

# %%
#select only 70% of the data and perform shits on that
#X_sub, x_test, Y_sub, y_test = train_test_split(X, Y, test_size=0.10, random_state=42)

# %%
# Generate dummies for categorical data
df_dummy = pd.get_dummies(X,drop_first=True)

# %%
X
# Out:
#           Start_Lng  Start_Lat  Distance.mi.  Wind_Speed.mph.  Hour  \
# 0       -118.275482  34.153896         0.000              5.8  20.0
# 1        -75.250020  40.261747         0.103              6.0  13.0
# 2        -90.073829  29.980875         0.070             12.0  20.0
# 3        -77.102890  39.018870         0.230              5.8  17.0
# 4       -120.175670  45.743940         0.000             20.0  19.0
# ...             ...        ...           ...              ...   ...
# 2962774  -76.559240  43.060840         0.000              3.5  14.0
# 2962775  -96.562760  32.784410         0.000             17.0   8.0
# 2962776  -93.292750  44.419400         0.000              8.0   7.0
# 2962777 -122.121000  47.253830         0.000             13.0   8.0
# 2962778  -84.358500  33.580320         0.000              9.2   8.0
#
#          Time_Duration(min)
# 0                      44.0
# 1                     100.0
# 2                     116.0
# 3                     360.0
# 4                     240.0
# ...                     ...
# 2962774                30.0
# 2962775                45.0
# 2962776                33.0
# 2962777                29.0
# 2962778                29.0
#
# [2625915 rows x 6 columns]

# %%
X_tr, X_te, Y_tr, Y_te = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
num_neigh = np.arange(1,10)
acc_tr = np.empty(9)
acc_te = np.empty(9)

#trying out knn for diff values of num_neigh
for n in num_neigh:
    knn_model = KNeighborsClassifier(n_neighbors=n)
    knn_model.fit(X_tr,Y_tr)
    print("now going for ", str(n))
    acc_tr[n-1] = knn_model.score(X_tr,Y_tr)
    acc_te[n-1] = knn_model.score(X_te,Y_te)

# %%
dt_entropy = DecisionTreeClassifier(max_depth=8, criterion='entropy', random_state=1)


# Fit dt_entropy to the training set
dt_entropy.fit(X_tr, Y_tr)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=8, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1, splitter='best')

# %%
y_hat= dt_entropy.predict(X_te)

# Evaluate accuracy_entropy
accuracy_entropy = accuracy_score(Y_te, y_hat)


# Print accuracy_entropy
print('[Decision Tree -- entropy] accuracy_score: {:.3f}.'.format(accuracy_entropy))
# Out:
# [Decision Tree -- entropy] accuracy_score: 0.740.

# %%
rand_forest =RandomForestClassifier(n_estimators=40)

#Train the model using the training sets y_pred=clf.predict(X_test)
rand_forest.fit(X_tr,Y_tr)

y_hat2=rand_forest.predict(X_te)


# Get the accuracy score
acc=accuracy_score(Y_te, y_hat2)
acc
# Out:
# 0.8323013736025114

# %%
# testing for Kaggle
kaggle_df = pd.read_csv('test.csv')
kaggle_df
# Out:
#                 ID    Source    TMC           Start_Time             End_Time  \
# 0              A-1  MapQuest  201.0  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1              A-5  MapQuest  201.0  2016-02-08 07:39:07  2016-02-08 08:09:07
# 2              A-7  MapQuest  201.0  2016-02-08 07:59:35  2016-02-08 08:29:35
# 3             A-14  MapQuest  201.0  2016-02-08 08:37:07  2016-02-08 09:07:07
# 4             A-22  MapQuest  201.0  2016-02-08 10:24:27  2016-02-08 10:54:27
# ...            ...       ...    ...                  ...                  ...
# 1269757  A-4239383      Bing    NaN  2019-08-23 15:24:47  2019-08-23 15:54:05
# 1269758  A-4239389      Bing    NaN  2019-08-23 15:45:43  2019-08-23 16:14:31
# 1269759  A-4239400      Bing    NaN  2019-08-23 17:43:56  2019-08-23 18:12:27
# 1269760  A-4239402      Bing    NaN  2019-08-23 18:03:25  2019-08-23 18:32:01
# 1269761  A-4239404      Bing    NaN  2019-08-23 19:00:21  2019-08-23 19:28:49
#
#          Start_Lat   Start_Lng   End_Lat   End_Lng  Distance.mi.  ...  \
# 0        39.865147  -84.058723       NaN       NaN         0.010  ...
# 1        39.627781  -84.188354       NaN       NaN         0.010  ...
# 2        39.758274  -84.230507       NaN       NaN         0.000  ...
# 3        39.790760  -84.241547       NaN       NaN         0.010  ...
# 4        39.773346  -84.224686       NaN       NaN         0.000  ...
# ...            ...         ...       ...       ...           ...  ...
# 1269757  34.629370 -118.153000  34.62937 -118.1530         0.000  ...
# 1269758  34.043650 -118.443700  34.04934 -118.4484         0.476  ...
# 1269759  33.741700 -117.837100  33.73917 -117.8300         0.443  ...
# 1269760  34.002480 -117.379400  33.99888 -117.3709         0.543  ...
# 1269761  33.775450 -117.847800  33.77740 -117.8573         0.561  ...
#
#         Roundabout  Station   Stop Traffic_Calming Traffic_Signal  \
# 0            False    False  False           False          False
# 1            False    False  False           False           True
# 2            False    False  False           False          False
# 3            False    False  False           False           True
# 4            False    False  False           False          False
# ...            ...      ...    ...             ...            ...
# 1269757      False    False  False           False          False
# 1269758      False    False  False           False          False
# 1269759      False    False  False           False          False
# 1269760      False    False  False           False          False
# 1269761      False    False  False           False          False
#
#         Turning_Loop Sunrise_Sunset Civil_Twilight Nautical_Twilight  \
# 0              False          Night          Night             Night
# 1              False            Day            Day               Day
# 2              False            Day            Day               Day
# 3              False            Day            Day               Day
# 4              False            Day            Day               Day
# ...              ...            ...            ...               ...
# 1269757        False            Day            Day               Day
# 1269758        False            Day            Day               Day
# 1269759        False            Day            Day               Day
# 1269760        False            Day            Day               Day
# 1269761        False            Day            Day               Day
#
#         Astronomical_Twilight
# 0                       Night
# 1                         Day
# 2                         Day
# 3                         Day
# 4                         Day
# ...                       ...
# 1269757                   Day
# 1269758                   Day
# 1269759                   Day
# 1269760                   Day
# 1269761                   Day
#
# [1269762 rows x 48 columns]

# %%
kaggle_df['Start_Time'] = pd.to_datetime(kaggle_df['Start_Time'], errors='coerce')
kaggle_df['End_Time'] = pd.to_datetime(kaggle_df['End_Time'], errors='coerce')

# Extract year, month, day, hour and weekday
kaggle_df['month']=kaggle_df['Start_Time'].dt.strftime('%b')
kaggle_df['Hour']=kaggle_df['Start_Time'].dt.hour
kaggle_df['Weekday']=kaggle_df['Start_Time'].dt.strftime('%a')

# Extract the amount of time in the unit of minutes for each accident, round to the nearest integer
td='Time_Duration(min)'
kaggle_df[td]=round((kaggle_df['End_Time']-kaggle_df['Start_Time'])/np.timedelta64(1,'m'))
kaggle_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1269762 entries, 0 to 1269761
# Data columns (total 52 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   ID                     1269762 non-null  object
#  1   Source                 1269762 non-null  object
#  2   TMC                    814829 non-null   float64
#  3   Start_Time             1269762 non-null  datetime64[ns]
#  4   End_Time               1269762 non-null  datetime64[ns]
#  5   Start_Lat              1269762 non-null  float64
#  6   Start_Lng              1269762 non-null  float64
#  7   End_Lat                454933 non-null   float64
#  8   End_Lng                454933 non-null   float64
#  9   Distance.mi.           1269762 non-null  float64
#  10  Description            1269761 non-null  object
#  11  Number                 463175 non-null   float64
#  12  Street                 1269762 non-null  object
#  13  Side                   1269762 non-null  object
#  14  City                   1269726 non-null  object
#  15  County                 1269762 non-null  object
#  16  State                  1269762 non-null  object
#  17  Zipcode                1269403 non-null  object
#  18  Country                1269762 non-null  object
#  19  Timezone               1268434 non-null  object
#  20  Airport_Code           1267166 non-null  object
#  21  Weather_Timestamp      1251231 non-null  object
#  22  Temperature.F.         1243051 non-null  float64
#  23  Wind_Chill.F.          701759 non-null   float64
#  24  Humidity...            1241443 non-null  float64
#  25  Pressure.in.           1247125 non-null  float64
#  26  Visibility.mi.         1240378 non-null  float64
#  27  Wind_Direction         1245028 non-null  object
#  28  Wind_Speed.mph.        1126621 non-null  float64
#  29  Precipitation.in.      650809 non-null   float64
#  30  Weather_Condition      1240525 non-null  object
#  31  Amenity                1269762 non-null  bool
#  32  Bump                   1269762 non-null  bool
#  33  Crossing               1269762 non-null  bool
#  34  Give_Way               1269762 non-null  bool
#  35  Junction               1269762 non-null  bool
#  36  No_Exit                1269762 non-null  bool
#  37  Railway                1269762 non-null  bool
#  38  Roundabout             1269762 non-null  bool
#  39  Station                1269762 non-null  bool
#  40  Stop                   1269762 non-null  bool
#  41  Traffic_Calming        1269762 non-null  bool
#  42  Traffic_Signal         1269762 non-null  bool
#  43  Turning_Loop           1269762 non-null  bool
#  44  Sunrise_Sunset         1269725 non-null  object
#  45  Civil_Twilight         1269725 non-null  object
#  46  Nautical_Twilight      1269725 non-null  object
#  47  Astronomical_Twilight  1269725 non-null  object
#  48  month                  1269762 non-null  object
#  49  Hour                   1269762 non-null  int64
#  50  Weekday                1269762 non-null  object
#  51  Time_Duration(min)     1269762 non-null  float64
# dtypes: bool(13), datetime64[ns](2), float64(15), int64(1), object(21)
# memory usage: 393.6+ MB

# %%
feature_lst_test=['Start_Lng','Start_Lat',
             'Distance.mi.','State',
             'Temperature.F.','Humidity...',
             'Visibility.mi.','Amenity',
             'Crossing','Junction','No_Exit','Railway',
             'Station','Stop','Traffic_Signal',
             'Hour','Weekday', 'Time_Duration(min)']

# %%
# Select the dataset to include only the selected features
kag_sel=kaggle_df[feature_lst_test].copy()

# %%
kag_dummy = pd.get_dummies(kag_sel,drop_first=True)

# %%
null_df = kag_dummy.isna().sum().to_frame()
null_df.sort_values(by=0, ascending=False)

#fill Visibility.mi., Humidity..., Temperature.F.
list_nulls = ['Visibility.mi.', 'Humidity...', 'Temperature.F.']
for i in list_nulls:
    kag_dummy[i] = kag_dummy[i].fillna(kag_dummy[i].median())

kag_dummy.isna().sum().to_frame()
# Out:
#                 0
# Start_Lng       0
# Start_Lat       0
# Distance.mi.    0
# Temperature.F.  0
# Humidity...     0
# ...            ..
# Weekday_Sat     0
# Weekday_Sun     0
# Weekday_Thu     0
# Weekday_Tue     0
# Weekday_Wed     0
#
# [70 rows x 1 columns]

# %%
kag_te = rand_forest.predict(kag_dummy)
kag_te
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
kag_te.to_csv('test_results.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-7dfbf44a71ef> in <module>
# ----> 1 kag_te.to_csv('test_results.csv')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'to_csv'

# %% [markdown]
# # Trying a different set of columns

# %%
df.describe().T
# Out:
#                        count         mean           std        min        25%  \
# TMC                1901648.0   208.348254     21.236047  200.00000  201.00000
# Severity           2962779.0     2.305150      0.533466    1.00000    2.00000
# Start_Lat          2962779.0    36.397790      4.964845   24.55527   33.52025
# Start_Lng          2962779.0   -95.466527     17.354510 -124.62380 -117.35660
# End_Lat            1061131.0    36.898592      5.166983   24.57018   33.85400
# End_Lng            1061131.0   -98.597794     18.495270 -124.49780 -118.20730
# Distance.mi.       2962779.0     0.336481      1.616485    0.00000    0.00000
# Number             1081417.0  6131.773288  12495.013510    1.00000  898.00000
# Temperature.F.     2899590.0    61.488264     18.523924  -89.00000   49.00000
# Wind_Chill.F.      1634781.0    54.903686     22.720811  -89.00000   38.00000
# Humidity...        2895631.0    65.663194     22.735045    1.00000   49.00000
# Pressure.in.       2909032.0    29.693540      0.864541    0.00000   29.64000
# Visibility.mi.     2893495.0     9.112050      2.818845    0.00000   10.00000
# Wind_Speed.mph.    2626594.0     7.903770      5.339578    0.00000    4.60000
# Precipitation.in.  1516143.0     0.012379      0.163746    0.00000    0.00000
#
#                           50%         75%           max
# TMC                 201.00000   201.00000     406.00000
# Severity              2.00000     3.00000       4.00000
# Start_Lat            35.82550    40.18439      49.00220
# Start_Lng           -90.01895   -80.84698     -67.11317
# End_Lat              37.35016    40.72576      49.07500
# End_Lng             -94.39028   -80.87304     -67.10924
# Distance.mi.          0.00000     0.08900     441.75000
# Number             2893.00000  7328.00000  990415.00000
# Temperature.F.       63.00000    75.20000     203.00000
# Wind_Chill.F.        58.00000    73.00000     189.00000
# Humidity...          68.00000    85.00000     100.00000
# Pressure.in.         29.93000    30.08000      58.04000
# Visibility.mi.       10.00000    10.00000     140.00000
# Wind_Speed.mph.       7.00000    10.40000     984.00000
# Precipitation.in.     0.00000     0.00000      25.00000

# %%
new_sub = df[['Severity','Start_Lat','Start_Lng','Distance.mi.','Traffic_Signal','Wind_Speed.mph.']]
new_sub.drop_duplicates(inplace=True)
# Out:
# C:\Users\Mitsy\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
new_sub.isna().sum()
# Out:
# Severity                1
# Start_Lat               1
# Start_Lng               1
# Distance.mi.            1
# Traffic_Signal          1
# Wind_Speed.mph.    229331
# dtype: int64

# %%
#drop the rows with missing values
new_sub.dropna(subset=['Wind_Speed.mph.'],inplace=True)
# Out:
# C:\Users\Mitsy\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
X = new_sub.drop(columns=['Severity'],inplace=False)
Y = new_sub['Severity']

X_tr, X_te, Y_tr, Y_te = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
rand_forest =RandomForestClassifier(n_estimators=100)

#Train the model using the training sets y_pred=clf.predict(X_test)
rand_forest.fit(X_tr,Y_tr)

y_hat2=rand_forest.predict(X_te)


# Get the accuracy score
acc=accuracy_score(Y_te, y_hat2)
acc
# Out:
# 0.8199530854690154
